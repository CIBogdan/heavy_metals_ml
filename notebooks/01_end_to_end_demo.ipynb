# %% [markdown]
# # End-to-end demo (package)
#
# This notebook demonstrates how to run the pipelines via Python API.
# For CLI usage, see README.

# %%
import pandas as pd
from heavymetals.config import AppConfig
from heavymetals.preprocessing import FeatureSpec, infer_numeric_columns
from heavymetals.classification import train_random_forest_multiclass

# df = pd.read_csv('data/df_clean.csv')
print('Load your dataset: data/df_clean.csv')
